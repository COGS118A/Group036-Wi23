# %%
import pandas as pd 
import numpy as np 
from joblib import dump, load

# %%
#read_csv into file
full_features = pd.read_csv('full_features.csv')
#drop yield_class from dataset
full_features = full_features.drop(['yield_class'], axis = 1)

# %%
#SVM model important features

# Load the saved model
model = load('svm_model.pkl')

# Get feature importance scores and corresponding feature names
feature_importance = abs(model.named_steps['clf'].coef_[0])
feature_names = full_features.columns

# Create a list of tuples containing feature names and importance scores
feature_scores = list(zip(feature_names, feature_importance))

# Sort the list by importance score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Print feature names and importance scores
print("\nFeature Importance Scores:\n")
for feature, score in feature_scores:
    print(feature,':\n', score)
# Out:
# Feature Importance Scores:
#
# month :
#  0.2464663468218625
# ranch_36 :
#  0.1459412770365943
# ranch_17 :
#  0.14045157821300747
# variety_ALLISON - SHEEGENE 20 :
#  0.12200719543273073
# color_RED :
#  0.11087547950756509
# variety_ARRA 28 - ARRA PASSION PUNCH :
#  0.10932398482226545
# ranch_4 :
#  0.09981539243141768
# year_planted_grafted :
#  0.09727382770745052
# variety_SUGRAONE :
#  0.09516879901706078
# variety_AUTUMN ROYAL :
#  0.09244816910781342
# variety_SCARLET ROYAL :
#  0.09215723824871493
# variety_RED GLOBE :
#  0.0915875676407014
# variety_ARRA 32 - ARRA MYSTIC DREAM :
#  0.08387948203783512
# variety_ARRA 27 - ARRA MYSTIC STAR :
#  0.08103982225384791
# variety_ARRA 29 - ARRA PASSION FIRE :
#  0.07073433586609254
# ranch_12 :
#  0.06874407493327402
# ranch_33 :
#  0.06556516410783376
# ranch_19 :
#  0.06408655030625841
# variety_THOMPSON SEEDLESS :
#  0.06185624786316012
# ranch_29 :
#  0.06163066333552108
# variety_AUTUMN KING :
#  0.060581604985072195
# ranch_37 :
#  0.056926926540402226
# age :
#  0.05662756823564622
# variety_CANDY HEARTS :
#  0.0527593957543491
# day :
#  0.04541935972504792
# ranch_10 :
#  0.043165346283381374
# Daily _Low :
#  0.041381841315996246
# ranch_2 :
#  0.0398335562413515
# variety_ARRA 34 - YUM-BO :
#  0.03942375593880226
# ranch_30 :
#  0.03739702362131979
# variety_ARRA 15 - SWEETIES :
#  0.03591975634705077
# variety_EXPERIMENTAL 80B-30+9 :
#  0.03457241126962878
# variety_FLAME SEEDLESS :
#  0.034036087051783584
# variety_SWEET SCARLET :
#  0.030768587555661392
# variety_SWEET GLOBE :
#  0.029596355730396068
# variety_EXPERIMENTAL 95B-59+6 :
#  0.02881487030075399
# ranch_35 :
#  0.02706155266350472
# variety_ARD 35 - FIRE CRUNCH :
#  0.026987560867317333
# variety_ARRA11 - HONEY BLOSSOM :
#  0.02613186317378827
# ranch_50 :
#  0.025882244755185593
# ranch_3 :
#  0.025841000920305796
# ranch_20 :
#  0.025532351282518
# variety_ARD 39 - SUNNY POP :
#  0.023770210504189728
# variety_IVORY - SHEEGENE 21 :
#  0.023271195154303512
# ranch_1 :
#  0.021752621718176057
# ranch_14 :
#  0.02141584498740384
# variety_EXPERIMENTAL :
#  0.01842511110849894
# ranch_16 :
#  0.01743199894585588
# ranch_18 :
#  0.015936827807602343
# variety_EXP 24A-15+3 :
#  0.015621337789133596
# variety_ARRA 30 - SUGAR DROP :
#  0.013190640058312985
# variety_ARD 36 - CHERRY CRUSH :
#  0.012646854134532759
# variety_EARLY SWEET :
#  0.007988462390498458
# variety_ARRA 33 - HONEY POP :
#  0.006053617193484051
# Precipitation  :
#  0.0055097225585985414
# ranch_32 :
#  0.002276003883601543
# variety_EXP 7A-40+1 :
#  0.0008899007407996797
# Daily_High :
#  0.0006103908944707559
# ranch_31 :
#  0.00030830732459015604
# year :
#  0.0
# color_BLACK :
#  0.0
# color_GREEN :
#  0.0
# variety_ARRA 16 :
#  0.0
# variety_CRIMSON SEEDLESS :
#  0.0
# ranch_15 :
#  0.0
# ranch_34 :
#  0.0

# %%
#Gradient Boosting Model important features

model = load('GB_model.pkl')

# Get feature importance scores and corresponding feature names
feature_importance = model.named_steps['clf'].feature_importances_
feature_names = full_features.columns

# Create a list of tuples containing feature names and importance scores
feature_scores = list(zip(feature_names, feature_importance))

# Sort the list by importance score in descending order
feature_scores.sort(key=lambda x: x[1], reverse=True)

# Print feature names and importance scores
print("\nFeature Importance Scores:\n")
for feature, score in feature_scores:
    print(feature,':\n', score)
# Out:
# Feature Importance Scores:
#
# year_planted_grafted :
#  0.188921614562486
# month :
#  0.07858705348084327
# color_RED :
#  0.0708015518884302
# day :
#  0.059566038420171344
# year :
#  0.05869290872089347
# age :
#  0.05818230622564557
# Daily_High :
#  0.055759049512390614
# Daily _Low :
#  0.051111046701250586
# ranch_17 :
#  0.05033284884832397
# variety_SCARLET ROYAL :
#  0.04469283800739743
# ranch_14 :
#  0.0356392094784126
# ranch_32 :
#  0.02834533962318569
# ranch_19 :
#  0.020226426232324228
# variety_AUTUMN KING :
#  0.017130937516110622
# ranch_37 :
#  0.015140495280363818
# ranch_20 :
#  0.013306698468371644
# ranch_30 :
#  0.012601167315663733
# variety_ALLISON - SHEEGENE 20 :
#  0.012424428749219703
# variety_FLAME SEEDLESS :
#  0.012083943637360423
# variety_ARRA 29 - ARRA PASSION FIRE :
#  0.011923728487789434
# variety_ARRA 28 - ARRA PASSION PUNCH :
#  0.01143136303609877
# ranch_16 :
#  0.008899743383027046
# ranch_18 :
#  0.008877926224389836
# variety_AUTUMN ROYAL :
#  0.007910323485351324
# ranch_4 :
#  0.0074345711251424884
# ranch_29 :
#  0.005997454128022112
# ranch_12 :
#  0.0059834416567372635
# ranch_2 :
#  0.005359594389716812
# variety_EXPERIMENTAL :
#  0.004962834613189747
# color_GREEN :
#  0.004366987888348308
# variety_SUGRAONE :
#  0.004249962360293305
# ranch_33 :
#  0.003689967940851156
# variety_SWEET SCARLET :
#  0.0032844170330272484
# ranch_35 :
#  0.00262860116864356
# ranch_36 :
#  0.002530048291315051
# Precipitation  :
#  0.0023366723900928683
# variety_ARRA 34 - YUM-BO :
#  0.0018899566888525383
# variety_RED GLOBE :
#  0.0016426727526680726
# variety_ARRA 27 - ARRA MYSTIC STAR :
#  0.001509687798945798
# variety_ARD 36 - CHERRY CRUSH :
#  0.0014357220031251908
# variety_EXPERIMENTAL 80B-30+9 :
#  0.0014217521324935947
# ranch_10 :
#  0.0009051545219545126
# variety_ARRA 32 - ARRA MYSTIC DREAM :
#  0.0008912433439884788
# variety_CANDY HEARTS :
#  0.0008454032925907454
# ranch_15 :
#  0.0007266359824842316
# variety_CRIMSON SEEDLESS :
#  0.000706131154752385
# variety_ARD 35 - FIRE CRUNCH :
#  0.0005773454921643756
# variety_ARRA 15 - SWEETIES :
#  0.0005060167475737854
# variety_ARRA 30 - SUGAR DROP :
#  0.0004942423478217741
# variety_ARRA 33 - HONEY POP :
#  0.0003862310925036019
# variety_EXP 24A-15+3 :
#  0.00036617490666059305
# color_BLACK :
#  0.0002684796339306034
# variety_IVORY - SHEEGENE 21 :
#  1.3560759102558965e-05
# variety_EARLY SWEET :
#  4.907750595685582e-08
# variety_ARD 39 - SUNNY POP :
#  0.0
# variety_ARRA 16 :
#  0.0
# variety_ARRA11 - HONEY BLOSSOM :
#  0.0
# variety_EXP 7A-40+1 :
#  0.0
# variety_EXPERIMENTAL 95B-59+6 :
#  0.0
# variety_SWEET GLOBE :
#  0.0
# variety_THOMPSON SEEDLESS :
#  0.0
# ranch_1 :
#  0.0
# ranch_3 :
#  0.0
# ranch_31 :
#  0.0
# ranch_34 :
#  0.0
# ranch_50 :
#  0.0
